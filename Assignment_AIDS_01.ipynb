# %% [markdown]
# # Assignment No: 01
# ### Ai and Data science ___ SMIT
# - Topics:
# - String Functions,
# - Type Casting, Input,
# - Operators,
# - and If-Else (Nested)

# %%
Ful_name = "Hanifullah"
print(Ful_name.upper())
# Out:
# HANIFULLAH

# %%
Fav_Fruit = input("Enter your favourit friut name: ")
print(len(Fav_Fruit))
# Out:
# 5

# %%
Sentance = "Python is fun"
print(Sentance.replace("Python", "awesome"))
# Out:
# Python is fun

# %%
Sentance = "Hello World"
print(Sentance.index("World"))
# Out:
# 6

# %%
Email = "HanifKHANb66@.com"
print(Email.lower())
# Out:
# hanifkhanb66@.com

# %%
Sentance = "  python programming "
print(Sentance.strip())
# Out:
# python programming

# %%
count_words =    " welcom to programming"
print(count_words.count("o"))
# Out:
# 3

# %%
count_words = " welcome to coding"
print(count_words.count("o"))
# Out:
# 3

# %%
age = input("Enter your age: ")
age = int(age)
print(age)
# Out:
# 21

# %%
num = 15.99
num = int(num)
print(num)
# Out:
# 15

# %%
num1 = 4
num2 = 3
sum = num1 + num2
print(sum)
# Out:
# 7

# %%
num = 100
result = str(num)
print(result)
print(type(result))
# Out:
# 100
# <class 'str'>

# %%
price_float= 345.7
price_int = int(price_float)
print(price_int)
print(type(price_int))
# Out:
# 345
# <class 'int'>

# %%
a = 45
b = 23
sum = int(a) + int(b)
print(sum)
# Out:
# 68

# %%
x = 5.5
x = float(x)
x += 10
print(x)
# Out:
# 15.5

# %%
Name = input("Enter your name: ")
city_Name =input("Enter your city name: ")
print(f"Hello {Name}, Welcom to {city_Name}")
# Out:
# Hello Hanif khan, Welcom to Peshawer

# %%
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
product = x * y
print(product)
# Out:
# 35

# %%
Fav_color = input("Enter yoyur favourit color: ")
print(f" I also like {Fav_color} color")
# Out:
#  I also like White color

# %%
Birth_year = int(input("Enter birth year; "))
current_year = 2026
age = current_year - Birth_year
print(" your age is: ", age)
# Out:
#  your age is:  21

# %%
words = input("Enter word: ")
print(words * 5)
# Out:
# HanifHanifHanifHanifHanif

# %%
mobil_num = ' 03123456789'
print(type(mobil_num))
# Out:
# <class 'str'>

# %%
mobil_num = input("Enter your mobile number: ")
print("Ap ny ye  number type kya hm.", mobil_num)
# Out:
# Ap ny ye  number type kya hm. 03123456789

# %%
a = 10
b = 3
reminder = a % b
print(reminder)
# Out:
# 1

# %%
a = 15
b = 10
c = 20
a > b and a < c
# Out:
# True

# %%
num = int(input("Enter a number: "))
print(num > 100) 
print(num < 100)
# Out:
# False
# True

# %%
2 **5
# Out:
# 32

# %%
num = 2
num_powr = num ** 5
print(num_powr)
# Out:
# 32

# %%
a = 50
b = 100
compar = a == b
print(compar)
# Out:
# False

# %%
a = True
b = False
result = a or b
print(result)
# Out:
# True

# %%
a = 0
b = 4
result = a or b
print (result)
# Out:
# 4

# %%
num = int(input("Enter a number: "))
if num >= 0:
    print("Number is potive.")
else:
    print("Nmuber is nagitive")
# Out:
# Nmuber is nagitive

# %%
age = int(input("Enter your age: "))
if age > 18:
    print("Eligible for vote.")
else:
    print("Not eligible for vote")
# Out:
# Not eligible for vote

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Odd number

# %%
a = int(input("Enter first num:"))
b = int(input("Enter second number"))
if a > b:
    print("A is grether than B")
else:
    print("B is greather than A")
# Out:
# B is greather than A

# %%
student_marks = float(input("Enter student marks"))
if student_marks > 33:
    print("Pass")
else:
    print("fail")
# Out:
# Pass

# %%
text = input("Enter something: ")
if text == "":
    print("Empty string")
else:
    print("string is not empty")
# Out:
# string is not empty

# %%
password = input("Enter your password")
if password == 'python123':
    print("Access granted")
else:
    print("Access not granted")
# Out:
# Access granted

# %%
num = int(input("Enter a number"))
if num == 0:
    print("Number is zero")
else:
    print("Number is not zero")
# Out:
# Number is zero

# %%
marks = float(input("Enter student marks"))
if marks >= 90:
    grade = "A"
elif marks >= 80:
    grade = "B"
elif marks >=70:
    grade = "C"
else:
    grade = "D"

print(grade)
# Out:
# B

# %%
tamp = float(input("Enter tamprature: "))
if tamp > 30:
    print("Its Hot today")
elif tamp > 15:
    print("Normal tamprature today")
else:
    print("its cold today")
# Out:
# Its Hot today

# %%
check_num = int(input("Enter the number: "))

if check_num % 3 == 0 and check_num % 5 == 0:
    print("FizzBuzz- number divible  by both 3 and 5.")
elif check_num % 3 == 0:
    print("Fizz- number divible by 3.")
elif check_num % 5 == 0:
    print("Buzz- number divisible by 5")
else:
    print("Number not divisible by 3 nor 5.")
# Out:
# FizzBuzz- number divible  by both 3 and 5.

# %%
char = input("Enter a char: ")

if char in 'a, e, i, o,u':
    print("Vowel leter")
else:
    print("Consunent leter")
# Out:
# Vowel leter

# %%
Bill = float(input("Enter amount: "))

if Bill >= 5000:
    discount = Bill* 0.20
    print("Discount", discount)
elif Bill >= 2000:
    discount = Bill* 0.10
    print("Discount", discount)
else:
    print("No discount.")
# Out:
# Discount 250.0

# %%
age = int(input("Enter  age: "))

if age <= 12:
    print("Child")
elif age <= 19:
    print(" Teenager")
elif age <= 59:
    print("Adult")
else:
    print("Senior citizen")
# Out:
# Adult

# %%
year = int(input("Enter a year: "))

if year % 400 == 0:
    print("Leap year ")
elif year % 100 == 0:
    print("Not leap year")
elif year % 4 ==0:
    print("Leap  year")
else:
    print("Not leap year")
# Out:
# Leap year

# %%
day = int(input("Enter number: "))

if day == 1:
    print("Monday")
elif day == 2:
    print("Tuesday")
elif day == 3:
    print("Wednesday")
elif day == 4:
    print("Thursday")
elif day == 5:
    print("Friday")
elif day == 6:
    print("Saturday")
elif day == 7:
    print("Sunday")
else:
    print("Invalid number, out of 1 to 7.")
# Out:
# Friday

# %%
num1 = float(input("Enter first number: "))
num2 = float(input('Enter second number: '))
oparator = input("Enter oparator: ")

if oparator =='+':
    sum = num1 + num2
    print("sum", sum)
elif oparator =='-':
    diff = num1 - num2
    print("diff", diff)
elif oparator =='*':
    product = num1 * num2
    print("product", product)
elif oparator =='/':
    if num2 == 0:
        print("Error, zero sy divid nhi huga.")
    else:
        qutiant = num1 / num2
        print("qutiant", qutiant)
else:
    print("Invalid oparator.")
# Out:
# product 12.0

# %%
weight = float(input("Enter your wieght: "))
hieght = float(input("Enter your hieght: "))

bmi = weight / (hieght**2)
print("your bmi is: ", round(bmi , 2))

if bmi < 18.5:
    print("Category: underwieght")
elif bmi < 25: 
    print("Category: Normal")
elif bmi < 30:
    print("Category: overwight")
else:
    print("Categry: faatty")
# Out:
# your bmi is:  20.76
# Category: Normal
